# %% [markdown]
# # Metropolis Hastings

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %run MH_toy.py
# Out:
# Efficiency =  0.181

# %% [markdown]
# # ULA

# %%
# %run unadjusted_toy.py
